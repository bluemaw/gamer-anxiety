# %%
import os
import pandas as pd

# %%
os.chdir("../")

# %%
# !echo %cd%
# Out:
# c:\Users\gaiag\gamer-anxiety

# %%
filepath = "python/data/gaming_anxiety.csv"
nas = ["", " ", "NA", "N/A", "na", "n/a"]
df = pd.read_csv(filepath, na_values=nas, encoding="ISO-8859-1")

# %%
""" import matplotlib.pyplot as plt

columns_of_interest = ['GAD1', 'GAD2', 'GAD3', 'GAD4', 'GAD5', 'GAD6', 'GAD7', 'GADE', 'SWL1', 'SWL2', 'SWL3', 'SWL4', 'SWL5',
                       'Game', 'Platform', 'Hours', 'earnings','SPIN1', 'SPIN2', 'SPIN3', 'SPIN4', 'SPIN5', 'SPIN6',
                            'SPIN7', 'SPIN8', 'SPIN9', 'SPIN10', 'SPIN11', 'SPIN12', 'SPIN13',
                            'SPIN14', 'SPIN15', 'SPIN16', 'SPIN17', 'Narcissism', 'Gender', 'Age',
                            'Work', 'Degree', 'Birthplace', 'Residence', 'Reference', 'Playstyle',
                            'accept', 'GAD_T', 'SWL_T', 'SPIN_T']

for column in columns_of_interest:
    value_counts = df[column].value_counts()


    plt.figure(figsize=(6, 6))  # Adjust the figure size as needed
    plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=140)


    plt.title(f'Value Counts for {column}')


    plt.show() """
